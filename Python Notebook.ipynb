# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshs-har/bike-Sharing-Model/blob/main/Python%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

import statsmodel.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

import warnings
warnings.filterwarnings('ignore')


Bike = pd.read_csv('day.csv')

bike.head()

bike.shape

bike.info()

bike.describe()

bike.isnull().sum()

bike.drop(['instant','dteday'], axis=1, inplace=True)

bike['season']=bike['season'].map({
    1:'spring',
    2:'summer',
    3:'fall',
    4:'winter'
})

bike['weathersit'] = bike['weathersit'].map({
    1:'Clear',
    2:'Mist',
    3:'Light_Snow_Rain',
    4:'Heavy_Rain'
})

plt.figure(figsize=(12,10))
sns.heatmap(bike.corr(numeric_only=true),
            annot=True,
            cmap='Y1GnBu')
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(x='season',y='cnt',data=bike)
plt.show()

plt.figure(figsize=(8,5))
sns.boxplot(x='weathersit',y='cnt',data=bike)
plt.show()

plt.figure(figsize=(5,5))
sns.boxplot(x='yr',y='cnt',data=bike)
plt.show()

season=pd.get_dummies(
    bike['season'],
    drop_first=True,
    dtype=int
)

weather=pd.get_dummies(
    bike['weathersit'],
    drop_first=True,
    dtype=int
)

month=pd.get_dummies(
    bike['month'],
    prefix='month',
    drop_first=True,
    dtype=int
)

weekday=pd.get_dummies(
    bike['weekday'],
    prefix='weekday',
    drop_first=True,
    dtype=int
)

bike = pd.concat(
    [bike, season, weather, month, weekday],
    axis=1
)

bike.head()

bike.drop(
    ['season', 'weathersit','month','weekday'],
    axis=1,
    inplace=True
)

cnt = casual+registered

bike.drop(
    ['casual','registered'],
    axis=1,
    inplace=True
)

df_train, df_test = train_test_split(
    bike,
    train_size=0.7,
    random_state=100
)

print(df_train.shape)
print(df_test,shape)

scaler = MinMaxSacler()

num_vars - [
    'temp',
    'atemp',
    'hum',
    'windspeed',
    'cnt'
]

df_train[num_vars] = scaler.fit_transform(
    df_train(num_vars)
)

y_train = df_train.pop('cnt')
x_train = df_train

x_train_sm = sm.add_constant(x_train)

lr = sm.OLS(
    y_train,
    x_train_sm
).Fit()

lr.summary()

vif = pd.DataFrame()

vif['Features'] = X_train.columns

vif['VIF'] = [
    variance_inflation_factor(
        x_train.values,
        i
    )
    for i in range(x_train.shape[1])
]

vif.sort_values(
    by='VIF',
    ascending=False
)

x_train = x_train.drop(
    ['atemp'],
    axis=1
)

x_train_sm = sm.add_constant(x_train)

lr = sm.OLS(
    y_train,
    x_train_sm
).Fit()

print(lr.summary())

Final_Features = x_train.columns

x_train_final = sm.add_constant(
    y_train,
    x_train_final
).Fit()

print(final_model.summary())

residuals = final_model.resid

sns.histplot(
    residuals,
    kde=True
)

plt.show()

sns.scatterplot(
    x=final_model.fittedvalues,
    y=residuals
)

plt.axhline(
    y=0,
    color='red'
)

plt.show()

df_test[num_vars] = scaler.transform(
    df_test[num_vars]
)

y_test = df_test.pop('cnt')

x_test = df_test[Final_features]

x_test_sm = sm.add_constant(
    X_test
)

y_pred = final_model.predict(
    x_test_sm
)

y_pred.head()

from sklearn.metrics import r2_score

r2 = r2_score(
    y_test,
    y_pred
)

print("Test R2 Score:",r2)

plt.figure(figsize=(6,6))

plt.sacter(
    y_test,
    y_pred
)

plt.xlabel("Actual")

plt.ylabel("Predicted")

plt.title("Actual vs Predicted")

plt.show()
